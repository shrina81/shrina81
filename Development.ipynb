# %%
import numpy as np
import os

# %%
from tflite_model_maker.config import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector
import tensorflow as tf

# %%
spec = model_spec.get('efficientdet_lite2')
#model_name = 'ssd_mobilenet_v1_coco_2017_11_17'

#spec = model_spec.get('ssd_mobilenet_v1_coco_2017_11_17')

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %%
train_data, validation_data, test_data = object_detector.DataLoader.from_csv('C://Image Data//new development//training-labelled-data-copy.csv')
# Out:
# INFO:tensorflow:Cache will be stored in C:\Users\JC8AB37\AppData\Local\Temp\tmpgbzp_h87 with prefix filename train_8845fd0f37c150b143115eab8f622c48. Cache_prefix is C:\Users\JC8AB37\AppData\Local\Temp\tmpgbzp_h87\train_8845fd0f37c150b143115eab8f622c48
# INFO:tensorflow:Cache will be stored in C:\Users\JC8AB37\AppData\Local\Temp\tmpcdubnv20 with prefix filename val_8845fd0f37c150b143115eab8f622c48. Cache_prefix is C:\Users\JC8AB37\AppData\Local\Temp\tmpcdubnv20\val_8845fd0f37c150b143115eab8f622c48
# INFO:tensorflow:Cache will be stored in C:\Users\JC8AB37\AppData\Local\Temp\tmpac9a2au1 with prefix filename test_8845fd0f37c150b143115eab8f622c48. Cache_prefix is C:\Users\JC8AB37\AppData\Local\Temp\tmpac9a2au1\test_8845fd0f37c150b143115eab8f622c48
# INFO:tensorflow:On image 0
# INFO:tensorflow:On image 0
# INFO:tensorflow:On image 0

# %%
td=train_data.gen_dataset(spec)

# %%
td
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(64, 448, 448, 3), dtype=tf.float32, name=None), {'mean_num_positives': TensorSpec(shape=(64, 1), dtype=tf.float32, name=None), 'cls_targets_3': TensorSpec(shape=(64, 56, 56, 9), dtype=tf.int32, name=None), 'box_targets_3': TensorSpec(shape=(64, 56, 56, 36), dtype=tf.float32, name=None), 'cls_targets_4': TensorSpec(shape=(64, 28, 28, 9), dtype=tf.int32, name=None), 'box_targets_4': TensorSpec(shape=(64, 28, 28, 36), dtype=tf.float32, name=None), 'cls_targets_5': TensorSpec(shape=(64, 14, 14, 9), dtype=tf.int32, name=None), 'box_targets_5': TensorSpec(shape=(64, 14, 14, 36), dtype=tf.float32, name=None), 'cls_targets_6': TensorSpec(shape=(64, 7, 7, 9), dtype=tf.int32, name=None), 'box_targets_6': TensorSpec(shape=(64, 7, 7, 36), dtype=tf.float32, name=None), 'cls_targets_7': TensorSpec(shape=(64, 4, 4, 9), dtype=tf.int32, name=None), 'box_targets_7': TensorSpec(shape=(64, 4, 4, 36), dtype=tf.float32, name=None), 'source_ids': TensorSpec(shape=(64,), dtype=tf.float32, name=None), 'groundtruth_data': TensorSpec(shape=(64, 100, 7), dtype=tf.float32, name=None), 'image_scales': TensorSpec(shape=(64,), dtype=tf.float32, name=None), 'image_masks': TensorSpec(shape=(64, 0), dtype=tf.float32, name=None)})>

# %%
validation_data

# %%
#model = object_detector.create(train_data, model_spec=spec, batch_size=8, epochs=20, train_whole_model=True, validation_data=validation_data)

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=8,train_whole_model=True, validation_data=validation_data)
# Out:
# INFO:tensorflow:Retraining the models...
# Epoch 1/50
# 5/5 [==============================] - 134s 17s/step - det_loss: 1.7608 - cls_loss: 1.1340 - box_loss: 0.0125 - reg_l2_loss: 0.0759 - loss: 1.8367 - learning_rate: 0.0089 - gradient_norm: 1.6845 - val_det_loss: 1.7790 - val_cls_loss: 1.1066 - val_box_loss: 0.0134 - val_reg_l2_loss: 0.0759 - val_loss: 1.8549
# Epoch 2/50
# 5/5 [==============================] - 77s 17s/step - det_loss: 1.6430 - cls_loss: 1.0982 - box_loss: 0.0109 - reg_l2_loss: 0.0759 - loss: 1.7189 - learning_rate: 0.0100 - gradient_norm: 1.6251 - val_det_loss: 1.6571 - val_cls_loss: 1.0562 - val_box_loss: 0.0120 - val_reg_l2_loss: 0.0759 - val_loss: 1.7330
# Epoch 3/50
# 5/5 [==============================] - 77s 17s/step - det_loss: 1.5515 - cls_loss: 1.0437 - box_loss: 0.0102 - reg_l2_loss: 0.0759 - loss: 1.6274 - learning_rate: 0.0099 - gradient_norm: 1.5078 - val_det_loss: 1.5325 - val_cls_loss: 0.9699 - val_box_loss: 0.0113 - val_reg_l2_loss: 0.0759 - val_loss: 1.6084
# Epoch 4/50
# 5/5 [==============================] - 77s 17s/step - det_loss: 1.4058 - cls_loss: 0.9313 - box_loss: 0.0095 - reg_l2_loss: 0.0759 - loss: 1.4817 - learning_rate: 0.0099 - gradient_norm: 1.9561 - val_det_loss: 1.3717 - val_cls_loss: 0.8256 - val_box_loss: 0.0109 - val_reg_l2_loss: 0.0759 - val_loss: 1.4476
# Epoch 5/50
# 5/5 [==============================] - ETA: 0s - det_loss: 1.2881 - cls_loss: 0.8169 - box_loss: 0.0094 - reg_l2_loss: 0.0759 - loss: 1.3640 - learning_rate: 0.0098 - gradient_norm: 2.1751 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.138
# 5/5 [==============================] - 92s 20s/step - det_loss: 1.2939 - cls_loss: 0.8143 - box_loss: 0.0096 - reg_l2_loss: 0.0759 - loss: 1.3698 - learning_rate: 0.0098 - gradient_norm: 2.2037 - val_det_loss: 1.1607 - val_cls_loss: 0.6407 - val_box_loss: 0.0104 - val_reg_l2_loss: 0.0759 - val_loss: 1.2366
# Epoch 6/50
# 5/5 [==============================] - 75s 16s/step - det_loss: 1.1041 - cls_loss: 0.6729 - box_loss: 0.0086 - reg_l2_loss: 0.0759 - loss: 1.1800 - learning_rate: 0.0097 - gradient_norm: 2.6927 - val_det_loss: 1.2013 - val_cls_loss: 0.7168 - val_box_loss: 0.0097 - val_reg_l2_loss: 0.0759 - val_loss: 1.2773
# Epoch 7/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 1.0359 - cls_loss: 0.5991 - box_loss: 0.0087 - reg_l2_loss: 0.0759 - loss: 1.1119 - learning_rate: 0.0096 - gradient_norm: 2.5988 - val_det_loss: 1.0214 - val_cls_loss: 0.5829 - val_box_loss: 0.0088 - val_reg_l2_loss: 0.0759 - val_loss: 1.0973
# Epoch 8/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 0.9438 - cls_loss: 0.5455 - box_loss: 0.0080 - reg_l2_loss: 0.0759 - loss: 1.0197 - learning_rate: 0.0094 - gradient_norm: 4.1509 - val_det_loss: 0.9982 - val_cls_loss: 0.5768 - val_box_loss: 0.0084 - val_reg_l2_loss: 0.0759 - val_loss: 1.0742
# Epoch 9/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.8690 - cls_loss: 0.4826 - box_loss: 0.0077 - reg_l2_loss: 0.0759 - loss: 0.9449 - learning_rate: 0.0093 - gradient_norm: 2.4996 - val_det_loss: 0.9972 - val_cls_loss: 0.6220 - val_box_loss: 0.0075 - val_reg_l2_loss: 0.0759 - val_loss: 1.0731
# Epoch 10/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.8513 - cls_loss: 0.4652 - box_loss: 0.0077 - reg_l2_loss: 0.0759 - loss: 0.9273 - learning_rate: 0.0091 - gradient_norm: 2.4524 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.769
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.300
# 5/5 [==============================] - 88s 19s/step - det_loss: 0.8280 - cls_loss: 0.4585 - box_loss: 0.0074 - reg_l2_loss: 0.0759 - loss: 0.9039 - learning_rate: 0.0091 - gradient_norm: 2.5291 - val_det_loss: 0.8924 - val_cls_loss: 0.5101 - val_box_loss: 0.0076 - val_reg_l2_loss: 0.0759 - val_loss: 0.9683
# Epoch 11/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.8146 - cls_loss: 0.4704 - box_loss: 0.0069 - reg_l2_loss: 0.0759 - loss: 0.8906 - learning_rate: 0.0089 - gradient_norm: 2.9185 - val_det_loss: 1.0107 - val_cls_loss: 0.6241 - val_box_loss: 0.0077 - val_reg_l2_loss: 0.0759 - val_loss: 1.0867
# Epoch 12/50
# 5/5 [==============================] - 72s 16s/step - det_loss: 0.7112 - cls_loss: 0.3831 - box_loss: 0.0066 - reg_l2_loss: 0.0759 - loss: 0.7871 - learning_rate: 0.0087 - gradient_norm: 2.5279 - val_det_loss: 1.1385 - val_cls_loss: 0.8429 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.0759 - val_loss: 1.2144
# Epoch 13/50
# 5/5 [==============================] - 78s 17s/step - det_loss: 0.7231 - cls_loss: 0.3948 - box_loss: 0.0066 - reg_l2_loss: 0.0759 - loss: 0.7991 - learning_rate: 0.0085 - gradient_norm: 3.1080 - val_det_loss: 1.0872 - val_cls_loss: 0.7571 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.0760 - val_loss: 1.1631
# Epoch 14/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 0.6567 - cls_loss: 0.3598 - box_loss: 0.0059 - reg_l2_loss: 0.0760 - loss: 0.7326 - learning_rate: 0.0082 - gradient_norm: 2.7530 - val_det_loss: 1.4295 - val_cls_loss: 1.0742 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.0760 - val_loss: 1.5054
# Epoch 15/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.6787 - cls_loss: 0.3705 - box_loss: 0.0062 - reg_l2_loss: 0.0760 - loss: 0.7546 - learning_rate: 0.0080 - gradient_norm: 2.9718 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.425
# 5/5 [==============================] - 79s 17s/step - det_loss: 0.6796 - cls_loss: 0.3707 - box_loss: 0.0062 - reg_l2_loss: 0.0760 - loss: 0.7556 - learning_rate: 0.0080 - gradient_norm: 2.9479 - val_det_loss: 1.2661 - val_cls_loss: 0.9888 - val_box_loss: 0.0055 - val_reg_l2_loss: 0.0760 - val_loss: 1.3421
# Epoch 16/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.5960 - cls_loss: 0.3466 - box_loss: 0.0050 - reg_l2_loss: 0.0760 - loss: 0.6720 - learning_rate: 0.0077 - gradient_norm: 3.7495 - val_det_loss: 0.9790 - val_cls_loss: 0.6788 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.0760 - val_loss: 1.0550
# Epoch 17/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.6585 - cls_loss: 0.3484 - box_loss: 0.0062 - reg_l2_loss: 0.0760 - loss: 0.7344 - learning_rate: 0.0075 - gradient_norm: 2.9581 - val_det_loss: 1.0235 - val_cls_loss: 0.6915 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.0760 - val_loss: 1.0995
# Epoch 18/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.6590 - cls_loss: 0.3546 - box_loss: 0.0061 - reg_l2_loss: 0.0760 - loss: 0.7350 - learning_rate: 0.0072 - gradient_norm: 2.9629 - val_det_loss: 1.1241 - val_cls_loss: 0.8383 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.0760 - val_loss: 1.2000
# Epoch 19/50
# 5/5 [==============================] - 87s 19s/step - det_loss: 0.5461 - cls_loss: 0.3039 - box_loss: 0.0048 - reg_l2_loss: 0.0760 - loss: 0.6221 - learning_rate: 0.0069 - gradient_norm: 3.2763 - val_det_loss: 0.9764 - val_cls_loss: 0.7179 - val_box_loss: 0.0052 - val_reg_l2_loss: 0.0760 - val_loss: 1.0524
# Epoch 20/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.5546 - cls_loss: 0.3044 - box_loss: 0.0050 - reg_l2_loss: 0.0760 - loss: 0.6306 - learning_rate: 0.0066 - gradient_norm: 3.6313 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.880
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.425
# 5/5 [==============================] - 78s 17s/step - det_loss: 0.5549 - cls_loss: 0.3061 - box_loss: 0.0050 - reg_l2_loss: 0.0760 - loss: 0.6309 - learning_rate: 0.0066 - gradient_norm: 3.8475 - val_det_loss: 0.9236 - val_cls_loss: 0.6514 - val_box_loss: 0.0054 - val_reg_l2_loss: 0.0760 - val_loss: 0.9996
# Epoch 21/50
# 5/5 [==============================] - 91s 19s/step - det_loss: 0.5898 - cls_loss: 0.3269 - box_loss: 0.0053 - reg_l2_loss: 0.0760 - loss: 0.6658 - learning_rate: 0.0063 - gradient_norm: 4.2156 - val_det_loss: 0.7083 - val_cls_loss: 0.4608 - val_box_loss: 0.0049 - val_reg_l2_loss: 0.0760 - val_loss: 0.7843
# Epoch 22/50
# 5/5 [==============================] - 75s 16s/step - det_loss: 0.6055 - cls_loss: 0.3521 - box_loss: 0.0051 - reg_l2_loss: 0.0760 - loss: 0.6815 - learning_rate: 0.0060 - gradient_norm: 4.1380 - val_det_loss: 0.6553 - val_cls_loss: 0.4150 - val_box_loss: 0.0048 - val_reg_l2_loss: 0.0760 - val_loss: 0.7313
# Epoch 23/50
# 5/5 [==============================] - 72s 15s/step - det_loss: 0.4882 - cls_loss: 0.2725 - box_loss: 0.0043 - reg_l2_loss: 0.0760 - loss: 0.5642 - learning_rate: 0.0056 - gradient_norm: 2.5716 - val_det_loss: 0.6919 - val_cls_loss: 0.4523 - val_box_loss: 0.0048 - val_reg_l2_loss: 0.0760 - val_loss: 0.7679
# Epoch 24/50
# 5/5 [==============================] - 72s 15s/step - det_loss: 0.4870 - cls_loss: 0.2683 - box_loss: 0.0044 - reg_l2_loss: 0.0760 - loss: 0.5630 - learning_rate: 0.0053 - gradient_norm: 2.6454 - val_det_loss: 0.6924 - val_cls_loss: 0.4656 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.0760 - val_loss: 0.7684
# Epoch 25/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.4572 - cls_loss: 0.2586 - box_loss: 0.0040 - reg_l2_loss: 0.0760 - loss: 0.5332 - learning_rate: 0.0050 - gradient_norm: 2.8253 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.309
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.463
# 5/5 [==============================] - 78s 17s/step - det_loss: 0.4497 - cls_loss: 0.2550 - box_loss: 0.0039 - reg_l2_loss: 0.0760 - loss: 0.5257 - learning_rate: 0.0050 - gradient_norm: 2.8077 - val_det_loss: 0.6508 - val_cls_loss: 0.4077 - val_box_loss: 0.0049 - val_reg_l2_loss: 0.0760 - val_loss: 0.7269
# Epoch 26/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.4922 - cls_loss: 0.2845 - box_loss: 0.0042 - reg_l2_loss: 0.0760 - loss: 0.5682 - learning_rate: 0.0047 - gradient_norm: 2.8830 - val_det_loss: 0.6763 - val_cls_loss: 0.4329 - val_box_loss: 0.0049 - val_reg_l2_loss: 0.0760 - val_loss: 0.7523
# Epoch 27/50
# 5/5 [==============================] - 71s 15s/step - det_loss: 0.5150 - cls_loss: 0.2910 - box_loss: 0.0045 - reg_l2_loss: 0.0760 - loss: 0.5910 - learning_rate: 0.0044 - gradient_norm: 3.2732 - val_det_loss: 0.6114 - val_cls_loss: 0.3825 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.0760 - val_loss: 0.6875
# Epoch 28/50
# 5/5 [==============================] - 70s 15s/step - det_loss: 0.4772 - cls_loss: 0.2761 - box_loss: 0.0040 - reg_l2_loss: 0.0760 - loss: 0.5532 - learning_rate: 0.0041 - gradient_norm: 3.1790 - val_det_loss: 0.5802 - val_cls_loss: 0.3636 - val_box_loss: 0.0043 - val_reg_l2_loss: 0.0760 - val_loss: 0.6563
# Epoch 29/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.4950 - cls_loss: 0.2782 - box_loss: 0.0043 - reg_l2_loss: 0.0760 - loss: 0.5710 - learning_rate: 0.0037 - gradient_norm: 3.1333 - val_det_loss: 0.5930 - val_cls_loss: 0.3702 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.0760 - val_loss: 0.6690
# Epoch 30/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.4402 - cls_loss: 0.2592 - box_loss: 0.0036 - reg_l2_loss: 0.0760 - loss: 0.5162 - learning_rate: 0.0035 - gradient_norm: 2.9830 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.512
# 5/5 [==============================] - 78s 17s/step - det_loss: 0.4475 - cls_loss: 0.2651 - box_loss: 0.0036 - reg_l2_loss: 0.0760 - loss: 0.5235 - learning_rate: 0.0034 - gradient_norm: 3.1117 - val_det_loss: 0.5764 - val_cls_loss: 0.3553 - val_box_loss: 0.0044 - val_reg_l2_loss: 0.0760 - val_loss: 0.6524
# Epoch 31/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 0.4428 - cls_loss: 0.2667 - box_loss: 0.0035 - reg_l2_loss: 0.0760 - loss: 0.5188 - learning_rate: 0.0031 - gradient_norm: 3.4315 - val_det_loss: 0.5708 - val_cls_loss: 0.3402 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.0760 - val_loss: 0.6469
# Epoch 32/50
# 5/5 [==============================] - 72s 16s/step - det_loss: 0.4311 - cls_loss: 0.2466 - box_loss: 0.0037 - reg_l2_loss: 0.0760 - loss: 0.5071 - learning_rate: 0.0028 - gradient_norm: 2.9702 - val_det_loss: 0.5372 - val_cls_loss: 0.3355 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.0760 - val_loss: 0.6133
# Epoch 33/50
# 5/5 [==============================] - 76s 16s/step - det_loss: 0.4414 - cls_loss: 0.2553 - box_loss: 0.0037 - reg_l2_loss: 0.0760 - loss: 0.5174 - learning_rate: 0.0026 - gradient_norm: 2.8217 - val_det_loss: 0.5304 - val_cls_loss: 0.3155 - val_box_loss: 0.0043 - val_reg_l2_loss: 0.0760 - val_loss: 0.6064
# Epoch 34/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.4068 - cls_loss: 0.2408 - box_loss: 0.0033 - reg_l2_loss: 0.0760 - loss: 0.4828 - learning_rate: 0.0023 - gradient_norm: 2.8508 - val_det_loss: 0.5559 - val_cls_loss: 0.3149 - val_box_loss: 0.0048 - val_reg_l2_loss: 0.0760 - val_loss: 0.6320
# Epoch 35/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.3979 - cls_loss: 0.2374 - box_loss: 0.0032 - reg_l2_loss: 0.0760 - loss: 0.4739 - learning_rate: 0.0020 - gradient_norm: 2.9760 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.475
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.475
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.475
# 5/5 [==============================] - 77s 17s/step - det_loss: 0.3786 - cls_loss: 0.2277 - box_loss: 0.0030 - reg_l2_loss: 0.0760 - loss: 0.4546 - learning_rate: 0.0020 - gradient_norm: 2.9602 - val_det_loss: 0.5899 - val_cls_loss: 0.3277 - val_box_loss: 0.0052 - val_reg_l2_loss: 0.0760 - val_loss: 0.6659
# Epoch 36/50
# 5/5 [==============================] - 69s 15s/step - det_loss: 0.4581 - cls_loss: 0.2501 - box_loss: 0.0042 - reg_l2_loss: 0.0760 - loss: 0.5341 - learning_rate: 0.0018 - gradient_norm: 2.9431 - val_det_loss: 0.6089 - val_cls_loss: 0.3422 - val_box_loss: 0.0053 - val_reg_l2_loss: 0.0760 - val_loss: 0.6850
# Epoch 37/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 0.4011 - cls_loss: 0.2337 - box_loss: 0.0033 - reg_l2_loss: 0.0760 - loss: 0.4771 - learning_rate: 0.0015 - gradient_norm: 2.5695 - val_det_loss: 0.5874 - val_cls_loss: 0.3398 - val_box_loss: 0.0050 - val_reg_l2_loss: 0.0760 - val_loss: 0.6634
# Epoch 38/50
# 5/5 [==============================] - 78s 17s/step - det_loss: 0.4047 - cls_loss: 0.2428 - box_loss: 0.0032 - reg_l2_loss: 0.0760 - loss: 0.4808 - learning_rate: 0.0013 - gradient_norm: 3.5804 - val_det_loss: 0.5543 - val_cls_loss: 0.3299 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.0760 - val_loss: 0.6303
# Epoch 39/50
# 5/5 [==============================] - 88s 19s/step - det_loss: 0.3952 - cls_loss: 0.2335 - box_loss: 0.0032 - reg_l2_loss: 0.0760 - loss: 0.4712 - learning_rate: 0.0011 - gradient_norm: 2.5031 - val_det_loss: 0.5257 - val_cls_loss: 0.3199 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.0760 - val_loss: 0.6018
# Epoch 40/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.4117 - cls_loss: 0.2293 - box_loss: 0.0036 - reg_l2_loss: 0.0760 - loss: 0.4877 - learning_rate: 9.1823e-04 - gradient_norm: 3.4189 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.371
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.487
# 5/5 [==============================] - 87s 19s/step - det_loss: 0.4225 - cls_loss: 0.2317 - box_loss: 0.0038 - reg_l2_loss: 0.0760 - loss: 0.4985 - learning_rate: 9.0601e-04 - gradient_norm: 3.5173 - val_det_loss: 0.5178 - val_cls_loss: 0.3178 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.0760 - val_loss: 0.5938
# Epoch 41/50
# 5/5 [==============================] - 76s 16s/step - det_loss: 0.3874 - cls_loss: 0.2188 - box_loss: 0.0034 - reg_l2_loss: 0.0760 - loss: 0.4634 - learning_rate: 7.3061e-04 - gradient_norm: 2.8480 - val_det_loss: 0.5229 - val_cls_loss: 0.3176 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.0760 - val_loss: 0.5989
# Epoch 42/50
# 5/5 [==============================] - 75s 16s/step - det_loss: 0.4829 - cls_loss: 0.2709 - box_loss: 0.0042 - reg_l2_loss: 0.0760 - loss: 0.5589 - learning_rate: 5.7276e-04 - gradient_norm: 3.2672 - val_det_loss: 0.5387 - val_cls_loss: 0.3214 - val_box_loss: 0.0043 - val_reg_l2_loss: 0.0760 - val_loss: 0.6147
# Epoch 43/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 0.3824 - cls_loss: 0.2257 - box_loss: 0.0031 - reg_l2_loss: 0.0760 - loss: 0.4584 - learning_rate: 4.3311e-04 - gradient_norm: 2.6337 - val_det_loss: 0.5521 - val_cls_loss: 0.3258 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.0760 - val_loss: 0.6282
# Epoch 44/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 0.3645 - cls_loss: 0.2261 - box_loss: 0.0028 - reg_l2_loss: 0.0760 - loss: 0.4405 - learning_rate: 3.1221e-04 - gradient_norm: 2.7132 - val_det_loss: 0.5588 - val_cls_loss: 0.3267 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.0760 - val_loss: 0.6348
# Epoch 45/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.4245 - cls_loss: 0.2499 - box_loss: 0.0035 - reg_l2_loss: 0.0760 - loss: 0.5005 - learning_rate: 2.1667e-04 - gradient_norm: 3.3175 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.588
# 5/5 [==============================] - 84s 18s/step - det_loss: 0.4143 - cls_loss: 0.2451 - box_loss: 0.0034 - reg_l2_loss: 0.0760 - loss: 0.4903 - learning_rate: 2.1059e-04 - gradient_norm: 3.2007 - val_det_loss: 0.5548 - val_cls_loss: 0.3248 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.0760 - val_loss: 0.6308
# Epoch 46/50
# 5/5 [==============================] - 74s 16s/step - det_loss: 0.3612 - cls_loss: 0.2202 - box_loss: 0.0028 - reg_l2_loss: 0.0760 - loss: 0.4372 - learning_rate: 1.2864e-04 - gradient_norm: 2.6935 - val_det_loss: 0.5508 - val_cls_loss: 0.3230 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.0760 - val_loss: 0.6268
# Epoch 47/50
# 5/5 [==============================] - 73s 16s/step - det_loss: 0.3695 - cls_loss: 0.2193 - box_loss: 0.0030 - reg_l2_loss: 0.0760 - loss: 0.4455 - learning_rate: 6.6709e-05 - gradient_norm: 3.2403 - val_det_loss: 0.5463 - val_cls_loss: 0.3209 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.0760 - val_loss: 0.6224
# Epoch 48/50
# 5/5 [==============================] - 75s 16s/step - det_loss: 0.4174 - cls_loss: 0.2388 - box_loss: 0.0036 - reg_l2_loss: 0.0760 - loss: 0.4934 - learning_rate: 2.5051e-05 - gradient_norm: 3.0854 - val_det_loss: 0.5453 - val_cls_loss: 0.3212 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.0760 - val_loss: 0.6214
# Epoch 49/50
# 5/5 [==============================] - 75s 16s/step - det_loss: 0.3704 - cls_loss: 0.2154 - box_loss: 0.0031 - reg_l2_loss: 0.0760 - loss: 0.4465 - learning_rate: 3.8357e-06 - gradient_norm: 2.2444 - val_det_loss: 0.5414 - val_cls_loss: 0.3199 - val_box_loss: 0.0044 - val_reg_l2_loss: 0.0760 - val_loss: 0.6174
# Epoch 50/50
# 5/5 [==============================] - ETA: 0s - det_loss: 0.4083 - cls_loss: 0.2390 - box_loss: 0.0034 - reg_l2_loss: 0.0760 - loss: 0.4844 - learning_rate: 2.4660e-06 - gradient_norm: 2.8284 loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (800, 7)
# 0/800
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.384
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.575
# 5/5 [==============================] - 77s 17s/step - det_loss: 0.4149 - cls_loss: 0.2398 - box_loss: 0.0035 - reg_l2_loss: 0.0760 - loss: 0.4909 - learning_rate: 3.1509e-06 - gradient_norm: 2.6974 - val_det_loss: 0.5419 - val_cls_loss: 0.3205 - val_box_loss: 0.0044 - val_reg_l2_loss: 0.0760 - val_loss: 0.6179

# %%
model.evaluate(test_data)
# Out:
# 1/1 [==============================] - 10s 10s/step
#
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (1100, 7)
# 0/1100
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.10s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.089
# {'AP': 0.012460194,
#  'AP50': 0.05060506,
#  'AP75': 0.0,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.012460194,
#  'ARmax1': 0.055555556,
#  'ARmax10': 0.08888889,
#  'ARmax100': 0.08888889,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.08888889,
#  'AP_/brakedisc': 0.012460194,
#  'AP_/': -1.0}

# %%
model.export(export_dir='C://Image Data//model.tflite')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow_examples.lite.model_maker.core.task.model_spec.object_detector_spec.ExportModel object at 0x000001828C5D67C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow_examples.lite.model_maker.core.task.model_spec.object_detector_spec.ExportModel object at 0x000001828C5D67C8>, because it is not built.
# WARNING:absl:Found untraced functions such as restored_function_body, restored_function_body, restored_function_body, restored_function_body, restored_function_body while saving (showing 5 of 876). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\JC8AB37\AppData\Local\Temp\tmpvylma4k2\assets
# INFO:tensorflow:Assets written to: C:\Users\JC8AB37\AppData\Local\Temp\tmpvylma4k2\assets

# %%
#Adding the meta-data in existing model
#brakedisc
from tflite_support.metadata_writers import object_detector
from tflite_support.metadata_writers import writer_utils
from tflite_support import metadata
import flatbuffers
import os
from tensorflow_lite_support.metadata import metadata_schema_py_generated as _metadata_fb
from tensorflow_lite_support.metadata.python import metadata as _metadata
from tensorflow_lite_support.metadata.python.metadata_writers import metadata_info
from tensorflow_lite_support.metadata.python.metadata_writers import metadata_writer
from tensorflow_lite_support.metadata.python.metadata_writers import writer_utils
ObjectDetectorWriter = object_detector.MetadataWriter
_MODEL_PATH = "C:/Image Data/model.tflite"
_LABEL_FILE = "C:/Image Data/new development/labelmap.txt"   #make sure you have this file to avoid 'no metadata' error 
_SAVE_TO_PATH = "C:/Image Data/tflite_meta.tflite"
writer = ObjectDetectorWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [127.5], [127.5], [_LABEL_FILE])
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Verify the populated metadata and associated files.
displayer = metadata.MetadataDisplayer.with_model_file(_SAVE_TO_PATH)
print("Metadata populated:")
print(displayer.get_metadata_json())
print("Associated file(s) populated:")
print(displayer.get_packed_associated_file_list())
model_meta = _metadata_fb.ModelMetadataT()
model_meta.name = "BrakeDisc_Detector"
model_meta.description = (
    "Identify which of a known set of objects might be present and provide "
    "information about their positions within the given image or a video "
    "stream.")
# Creates input info.
input_meta = _metadata_fb.TensorMetadataT()
input_meta.name = "image"
input_meta.content = _metadata_fb.ContentT()
input_meta.content.contentProperties = _metadata_fb.ImagePropertiesT()
input_meta.content.contentProperties.colorSpace = (
    _metadata_fb.ColorSpaceType.RGB)
input_meta.content.contentPropertiesType = (
    _metadata_fb.ContentProperties.ImageProperties)
input_normalization = _metadata_fb.ProcessUnitT()
input_normalization.optionsType = (
    _metadata_fb.ProcessUnitOptions.NormalizationOptions)
input_normalization.options = _metadata_fb.NormalizationOptionsT()
input_normalization.options.mean = [127.5]
input_normalization.options.std = [127.5]
input_meta.processUnits = [input_normalization]
input_stats = _metadata_fb.StatsT()
input_stats.max = [255]
input_stats.min = [0]
input_meta.stats = input_stats
# Creates outputs info.
output_location_meta = _metadata_fb.TensorMetadataT()
output_location_meta.name = "location"
output_location_meta.description = "The locations of the detected boxes."
output_location_meta.content = _metadata_fb.ContentT()
output_location_meta.content.contentPropertiesType = (
    _metadata_fb.ContentProperties.BoundingBoxProperties)
output_location_meta.content.contentProperties = (
    _metadata_fb.BoundingBoxPropertiesT())
output_location_meta.content.contentProperties.index = [1, 0, 3, 2]
output_location_meta.content.contentProperties.type = (
    _metadata_fb.BoundingBoxType.BOUNDARIES)
output_location_meta.content.contentProperties.coordinateType = (
    _metadata_fb.CoordinateType.RATIO)
output_location_meta.content.range = _metadata_fb.ValueRangeT()
output_location_meta.content.range.min = 2
output_location_meta.content.range.max = 2
output_class_meta = _metadata_fb.TensorMetadataT()
output_class_meta.name = "category"
output_class_meta.description = "The categories of the detected boxes."
output_class_meta.content = _metadata_fb.ContentT()
output_class_meta.content.contentPropertiesType = (
    _metadata_fb.ContentProperties.FeatureProperties)
output_class_meta.content.contentProperties = (
    _metadata_fb.FeaturePropertiesT())
output_class_meta.content.range = _metadata_fb.ValueRangeT()
output_class_meta.content.range.min = 2
output_class_meta.content.range.max = 2
label_file = _metadata_fb.AssociatedFileT()
label_file.name = os.path.basename("labelmap.txt")
label_file.description = "Label of objects that this model can recognize."
label_file.type = _metadata_fb.AssociatedFileType.TENSOR_VALUE_LABELS
output_class_meta.associatedFiles = [label_file]
output_score_meta = _metadata_fb.TensorMetadataT()
output_score_meta.name = "score"
output_score_meta.description = "The scores of the detected boxes."
output_score_meta.content = _metadata_fb.ContentT()
output_score_meta.content.contentPropertiesType = (
    _metadata_fb.ContentProperties.FeatureProperties)
output_score_meta.content.contentProperties = (
    _metadata_fb.FeaturePropertiesT())
output_score_meta.content.range = _metadata_fb.ValueRangeT()
output_score_meta.content.range.min = 2
output_score_meta.content.range.max = 2
output_number_meta = _metadata_fb.TensorMetadataT()
output_number_meta.name = "number of detections"
output_number_meta.description = "The number of the detected boxes."
output_number_meta.content = _metadata_fb.ContentT()
output_number_meta.content.contentPropertiesType = (
    _metadata_fb.ContentProperties.FeatureProperties)
output_number_meta.content.contentProperties = (
    _metadata_fb.FeaturePropertiesT())
# Creates subgraph info.
group = _metadata_fb.TensorGroupT()
group.name = "detection result"
group.tensorNames = [
    output_location_meta.name, output_class_meta.name,
    output_score_meta.name
]
subgraph = _metadata_fb.SubGraphMetadataT()
subgraph.inputTensorMetadata = [input_meta]
subgraph.outputTensorMetadata = [
    output_location_meta, output_class_meta, output_score_meta,
    output_number_meta
]
subgraph.outputTensorGroups = [group]
model_meta.subgraphMetadata = [subgraph]
b = flatbuffers.Builder(0)
b.Finish(
    model_meta.Pack(b),
    _metadata.MetadataPopulator.METADATA_FILE_IDENTIFIER)
metadata_buf = b.Output()

# %% [markdown]
# # Test the TFLite model on the image

# %%
#@title Load the trained TFLite model and define some visualization functions

#@markdown This code comes from the TFLite Object Detection [Raspberry Pi sample](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).

import platform
import json
import cv2

from typing import List, NamedTuple
from tflite_support import metadata


Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
#@title Run object detection and show the detection results

#INPUT_IMAGE_URL = "https://storage.googleapis.com/cloud-ml-data/img/openimage/3/2520/3916261642_0a504acd60_o.jpg" #@param {type:"string"}
DETECTION_THRESHOLD = 0.3 #@param {type:"number"}

#TEMP_FILE = 'C://Image Data//training//train//nOK//20200226_134546.jpg'
TEMP_FILE = 'C://Image Data//training//test//OK//20220303_070941.jpg'

#!wget -q -O $TEMP_FILE $INPUT_IMAGE_URL
#im = Image.open(TEMP_FILE,)
import cv2
import numpy as np
from PIL import Image

img = cv2.imread(TEMP_FILE)
image_np = cv2.resize(img, dsize=(448, 448), interpolation=cv2.INTER_CUBIC)
#im.thumbnail((448, 448), Image.Resampling.LANCZOS)
#image_np = np.asarray(im,dtype=uint8)
#image_np = np.asarray(im,dtype=np.uint8)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path='model.tflite', options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)
# Out:
# <PIL.Image.Image image mode=RGB size=448x448>

# %%
detections
# Out:
# [Detection(bounding_box=Rect(left=28, top=45, right=376, bottom=248), categories=[Category(label='brakedisc', score=0.625, index=0)])]

# %%
image_np.shape
